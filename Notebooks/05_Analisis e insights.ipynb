# %% [markdown]
# # ANALISIS E INSIGHTS

# %% [markdown]
# En este apartado obtendremos las conclusiones más relevantes para el objetivo utilizando todo el trabajo de preparación que hemos hecho y las técnicas de Business Analytics.
#
# Para ello empezaremos dando respuesta a las preguntas semilla y en el proceso iremos obteniendo *insights* valiosos que nos lleven a nuevas preguntas o a la aplicación de ciertas técnicas.

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

# %% [markdown]
# ## CARGA DE DATOS

# %%
con = sa.create_engine('sqlite:///../Datos/airbnb.db')

df = pd.read_sql('df_preparado', con = con)

df.head()
# Out:
#    level_0  index     id                                      name    host_id  \
# 0        0      0   6369  Rooftop terrace room ,  ensuite bathroom      13660
# 1        1      1  21853                      Bright and airy room      83531
# 2        2      2  23001         Apartmento Arganzuela- Madrid Rio      82175
# 3        3      3  24805                    Gran Via Studio Madrid  346366726
# 4        4      4  26825        Single Room whith private Bathroom     114340
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2          Arganzuela         Legazpi  40.38840   -3.69511  Entire home/apt
# 3              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 4          Arganzuela         Legazpi  40.38975   -3.69018     Private room
#
#    price  minimum_nights  calculated_host_listings_count  availability_365  \
# 0     60               1                               2               180
# 1     31               4                               2               364
# 2     50              15                               5               222
# 3     92               5                               1               115
# 4     26               2                               1               349
#
#                                          description host_is_superhost  \
# 0  Excellent connection with the AIRPORT and EXHI...                 t
# 1  We have a quiet and sunny room with a good vie...                 f
# 2  Apartamento de tres dormitorios dobles, gran s...                 f
# 3  Studio located 50 meters from Gran Via, next t...                 f
# 4  Nice and cozy roon for one person with a priva...                 f
#
#    accommodates  bedrooms  beds  number_of_reviews  review_scores_rating  \
# 0             2       1.0   1.0                 80                  4.87
# 1             1       1.0   1.0                 33                  4.58
# 2             6       3.0   5.0                  0                   NaN
# 3             3       1.0   1.0                 12                  4.92
# 4             1       1.0   1.0                149                  4.68
#
#    review_scores_communication  review_scores_location  precio_m2    distrito  \
# 0                         4.89                    4.77       5098   Chamartín
# 1                         4.82                    4.21       2267      Latina
# 2                          NaN                     NaN       4085  Arganzuela
# 3                         5.00                    5.00       4827      Centro
# 4                         4.71                    4.70       4085  Arganzuela
#
#    precio_total  ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 0          60.0         50        01_Una               0-3       1-2
# 1          31.0          0        01_Una               0-3       1-2
# 2          50.0         39       03_Tres              5-16      4-24
# 3          92.0         68        01_Una               0-3       1-2
# 4          26.0          4        01_Una               0-3       1-2
#
#   number_of_reviews_disc  m2  precio_compra   pdi_sol
# 0                 50-744  50       178430.0  5.032039
# 1                   6-49  50        79345.0  3.521406
# 2                    1-5  90       257355.0  3.226963
# 3                   6-49  50       168945.0  0.591065
# 4                 50-744  50       142975.0  3.200942

# %% [markdown]
# ## ANALISIS

# %% [markdown]
# ### Analisis sobre el precio

# %% [markdown]
# **¿Cual es el precio medio? ¿y el rango de precios?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por precio medio de alquiler?**

# %%
df.precio_total.describe()
# Out:
# count    17710.000000
# mean       149.027770
# std        523.211567
# min         20.000000
# 25%         43.000000
# 50%         70.000000
# 75%        112.000000
# max      22400.000000
# Name: precio_total, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.precio_total.median()
# Out:
# 70.0

# %%
df.groupby('distrito').precio_total.median().sort_values(ascending = False)
# Out:
# distrito
# San Blas - Canillejas    90.0
# Salamanca                88.0
# Centro                   76.0
# Chamartín                74.0
# Chamberí                 70.0
# Hortaleza                69.0
# Retiro                   68.0
# Tetuán                   66.0
# Moncloa - Aravaca        61.0
# Fuencarral - El Pardo    60.0
# Arganzuela               58.0
# Vicálvaro                53.0
# Ciudad Lineal            50.0
# Barajas                  49.5
# Carabanchel              48.0
# Villa de Vallecas        47.5
# Latina                   47.0
# Usera                    42.0
# Villaverde               42.0
# Moratalaz                40.0
# Puente de Vallecas       40.0
# Name: precio_total, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando:

# %%
df.loc[df.distrito == 'San Blas - Canillejas'].sort_values('precio_total',ascending = False).head(10)
# Out:
#        level_0  index        id  \
# 9290      9290   9290  34600594
# 9662      9662   9662  34826962
# 10189    10189  10189  35149419
# 9668      9668   9668  34833756
# 9878      9878   9878  34970236
# 9748      9748   9748  34882596
# 9173      9173   9173  34522997
# 9831      9831   9831  34933116
# 10092    10092  10092  35091283
# 10404    10404  10404  35251141
#
#                                                     name    host_id  \
# 9290                                  3 rooms near Wanda   38951538
# 9662                                         Pozos rooms  222068421
# 10189       CHALET FOR THE FINAL CHAMPIONS LEAGUE MADRID  143732655
# 9668                               Wanda Champions Final   29628177
# 9878   Habitaciones cerca Wanda Metropolitano (Champi...  263474389
# 9748                                  2 rooms near wanda   38951538
# 9173     Beautiful Penthouse next to Wanda Metropolitano  260551569
# 9831                       FINAL CHAMPIONS LEAGUE MADRID  263232278
# 10092                             FINAL CHAMPIONS LEAGUE  264225539
# 10404        Se alquila para final de la champion league  265376740
#
#          neighbourhood_group neighbourhood  latitude  longitude  \
# 9290   San Blas - Canillejas         Arcos  40.42105   -3.61457
# 9662   San Blas - Canillejas         Arcos  40.41927   -3.61555
# 10189  San Blas - Canillejas    Canillejas  40.44937   -3.61633
# 9668   San Blas - Canillejas         Rosas  40.42622   -3.60502
# 9878   San Blas - Canillejas         Arcos  40.41920   -3.61229
# 9748   San Blas - Canillejas         Arcos  40.41948   -3.61427
# 9173   San Blas - Canillejas    Canillejas  40.43686   -3.61093
# 9831   San Blas - Canillejas      Simancas  40.43968   -3.61933
# 10092  San Blas - Canillejas         Rejas  40.44592   -3.58746
# 10404  San Blas - Canillejas    Canillejas  40.44292   -3.60764
#
#              room_type  price  minimum_nights  calculated_host_listings_count  \
# 9290      Private room   2800               1                               2
# 9662      Private room   3000               1                               1
# 10189  Entire home/apt   6000               1                               1
# 9668      Private room   2700               1                               1
# 9878      Private room    800               1                               1
# 9748      Private room   1500               1                               2
# 9173      Private room   2000               1                               1
# 9831      Private room   2000               2                               1
# 10092     Private room   1000               1                               1
# 10404  Entire home/apt   3000               1                               1
#
#        availability_365                                        description  \
# 9290                  0                     3 rooms 15´walking from Wanda.
# 9662                 88  Cerca nos podemos encontrar un centro comercia...
# 10189               365  We are talking about one of the last villas fo...
# 9668                  0  Somos una pareja joven educados y muy sociable...
# 9878                 88  Se alquilan 5 habitaciones, cada una para 2 hu...
# 9748                363  2 rooms near Wanda stadium (20' walking) with ...
# 9173                  0  Wonderful penthouse in a lovely duplex next to...
# 9831                365  Near (15 minutes walking) to WANDA STADIUM.<br...
# 10092               180  Desayuno, comida y cena incluida. Traslados al...
# 10404               365                                               None
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 9290                  f             6       3.0   5.0                  0
# 9662                  f             4       2.0   3.0                  0
# 10189                 f             6       4.0   5.0                  0
# 9668                  f             5       2.0   3.0                  0
# 9878                  f            10       5.0   8.0                  0
# 9748                  f             4       2.0   4.0                  0
# 9173                  f             4       1.0   3.0                  0
# 9831                  f             5       3.0   3.0                  0
# 10092                 f             6       2.0   6.0                  0
# 10404                 f             1       2.0   4.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 9290                    NaN                          NaN
# 9662                    NaN                          NaN
# 10189                   NaN                          NaN
# 9668                    NaN                          NaN
# 9878                    NaN                          NaN
# 9748                    NaN                          NaN
# 9173                    NaN                          NaN
# 9831                    NaN                          NaN
# 10092                   NaN                          NaN
# 10404                   NaN                          NaN
#
#        review_scores_location  precio_m2               distrito  precio_total  \
# 9290                      NaN       2591  San Blas - Canillejas        9800.0
# 9662                      NaN       2591  San Blas - Canillejas        6300.0
# 10189                     NaN       2591  San Blas - Canillejas        6000.0
# 9668                      NaN       2591  San Blas - Canillejas        5670.0
# 9878                      NaN       2591  San Blas - Canillejas        4480.0
# 9748                      NaN       2591  San Blas - Canillejas        4200.0
# 9173                      NaN       2591  San Blas - Canillejas        4200.0
# 9831                      NaN       2591  San Blas - Canillejas        4200.0
# 10092                     NaN       2591  San Blas - Canillejas        4200.0
# 10404                     NaN       2591  San Blas - Canillejas        3000.0
#
#        ocupacion    bedrooms_disc accommodates_disc beds_disc  \
# 9290         100          03_Tres              5-16      4-24
# 9662          75           02_Dos                 4         3
# 10189          0  04_Cuatro o mas              5-16      4-24
# 9668         100           02_Dos              5-16         3
# 9878          75  04_Cuatro o mas              5-16      4-24
# 9748           0           02_Dos                 4      4-24
# 9173         100           01_Una                 4         3
# 9831           0          03_Tres              5-16         3
# 10092         50           02_Dos              5-16      4-24
# 10404          0           02_Dos               0-3      4-24
#
#       number_of_reviews_disc   m2  precio_compra    pdi_sol
# 9290                     1-5   90       163233.0   7.532233
# 9662                     1-5   70       126959.0   7.439364
# 10189                    1-5  120       217644.0   8.212429
# 9668                     1-5   70       126959.0   8.391922
# 9878                     1-5  150       272055.0   7.714952
# 9748                     1-5   70       126959.0   7.548577
# 9173                     1-5   50        90685.0   8.138310
# 9831                     1-5   90       163233.0   7.557076
# 10092                    1-5   70       126959.0  10.334061
# 10404                    1-5   70       126959.0   8.610212

# %% [markdown]
# Vemos que son precios en el entorno de los 3.000 - 5.000 euros!
#
# Al leer la descripción nos damos cuenta de todos estos precios están definidos por la final de la Champions League.
#
# Lo cual es un insight interesante:
#
# **Insight 1: Pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos.**
#
# ¿Tendría sentido generar un producto de alquiler que consista en alquilar de forma "normal" a un precio inferior al mercado con la condición de que el inquilino deje el piso libre para alquilarlo "turísticamente" en fechas señaladas?

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
temp = df.groupby('distrito')[['precio_total','precio_compra']].median()
temp
# Out:
#                        precio_total  precio_compra
# distrito
# Arganzuela                     58.0       142975.0
# Barajas                        49.5       119315.0
# Carabanchel                    48.0        74305.0
# Centro                         76.0       168945.0
# Chamartín                      74.0       178430.0
# Chamberí                       70.0       188335.0
# Ciudad Lineal                  50.0       102900.0
# Fuencarral - El Pardo          60.0       124880.0
# Hortaleza                      69.0       135485.0
# Latina                         47.0        79345.0
# Moncloa - Aravaca              61.0       141155.0
# Moratalaz                      40.0        87500.0
# Puente de Vallecas             40.0        67130.0
# Retiro                         68.0       167580.0
# Salamanca                      88.0       213990.0
# San Blas - Canillejas          90.0        90685.0
# Tetuán                         66.0       128730.0
# Usera                          42.0        69825.0
# Vicálvaro                      53.0        84105.0
# Villa de Vallecas              47.5        82390.0
# Villaverde                     42.0        59255.0

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# Existe una clara correlación entre el precio de compra en cada distrito y el precio que podremos cobrar.
#
# Claramente se perciben tres clusters de bajo-bajo, medio-medio y alto-alto.
#
# Y la excepción de San Blas que ya sabemos por qué es.
#
# Por tanto como era esperable no hay a priori ningún "chollo" claro a este nivel.
#
# Vamos a repetir el análisis a nivel de barrio a ver si identificamos algo.

# %%
temp = df.groupby('neighbourhood')[['precio_total','precio_compra']].median()
temp
# Out:
#                precio_total  precio_compra
# neighbourhood
# Abrantes               35.5        74305.0
# Acacias                53.8       142975.0
# Adelfas                54.0       234612.0
# Aeropuerto             41.3       119315.0
# Aguilas                47.0        79345.0
# ...                     ...            ...
# Valverde               62.5       124880.0
# Ventas                 42.0       102900.0
# Vinateros              50.0        87500.0
# Vista Alegre           50.0        74305.0
# Zofío                  36.4        69825.0
#
# [128 rows x 2 columns]

# %%
plt.figure(figsize = (16,20))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 3 barrios que sobresalen, posiblemente los 3 sean de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo: Simancas, Ambroz, Marroquina, San Juan Bautista.
#     * Medio: El Plantio, Valdemarín, Valdefuentes.
#     * Medio-alto: Jerónimos, Fuentela reina.
#     * Alto: Recoletos.
#
# **Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación coste-ingresos y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interesa invertir.**

# %%
df.loc[df.neighbourhood.isin(['Rosas','Canillejas','Hellin']),'distrito'].unique()
# Out:
# array(['San Blas - Canillejas'], dtype=object)

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['precio_total','precio_compra']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]
minicubo_precio
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3       1-2                 50-744
# 1            01_Una               0-3       1-2                   6-49
# 2           03_Tres              5-16      4-24                    1-5
# 3            01_Una               0-3       1-2                   6-49
# 4            01_Una               0-3       1-2                 50-744
# ...             ...               ...       ...                    ...
# 17705        01_Una               0-3       1-2                    1-5
# 17706        01_Una               0-3       1-2                    1-5
# 17707        01_Una               0-3       1-2                    1-5
# 17708        01_Una               0-3       1-2                    1-5
# 17709        01_Una               0-3       1-2                    1-5
#
#        precio_total  precio_compra
# 0              60.0       178430.0
# 1              31.0        79345.0
# 2              50.0       257355.0
# 3              92.0       168945.0
# 4              26.0       142975.0
# ...             ...            ...
# 17705          29.0       168945.0
# 17706          29.0       168945.0
# 17707          29.0       168945.0
# 17708          29.0       213990.0
# 17709          33.0       168945.0
#
# [17710 rows x 6 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','precio_compra'])
minicubo_precio
# Out:
#        precio_total  precio_compra                variable    value
# 0              60.0       178430.0           bedrooms_disc   01_Una
# 1              31.0        79345.0           bedrooms_disc   01_Una
# 2              50.0       257355.0           bedrooms_disc  03_Tres
# 3              92.0       168945.0           bedrooms_disc   01_Una
# 4              26.0       142975.0           bedrooms_disc   01_Una
# ...             ...            ...                     ...      ...
# 70835          29.0       168945.0  number_of_reviews_disc      1-5
# 70836          29.0       168945.0  number_of_reviews_disc      1-5
# 70837          29.0       168945.0  number_of_reviews_disc      1-5
# 70838          29.0       213990.0  number_of_reviews_disc      1-5
# 70839          33.0       168945.0  number_of_reviews_disc      1-5
#
# [70840 rows x 4 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','precio_compra']].agg('median')
minicubo_precio
# Out:
#                                         precio_total  precio_compra
# variable               value
# accommodates_disc      0-3                      50.0       168945.0
#                        4                        86.0       168945.0
#                        5-16                    126.0       236523.0
# bedrooms_disc          01_Una                   56.0       168945.0
#                        02_Dos                  100.0       236523.0
#                        03_Tres                 140.0       304101.0
#                        04_Cuatro o mas         204.0       405468.0
# beds_disc              1-2                      59.0       168945.0
#                        3                       100.0       236523.0
#                        4-24                    139.0       257355.0
# number_of_reviews_disc 1-5                      70.0       168945.0
#                        50-744                   68.0       168945.0
#                        6-49                     69.0       168945.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_precio.loc['bedrooms_disc']
# Out:
#                  precio_total  precio_compra
# value
# 01_Una                   56.0       168945.0
# 02_Dos                  100.0       236523.0
# 03_Tres                 140.0       304101.0
# 04_Cuatro o mas         204.0       405468.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['bedrooms_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['bedrooms_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de habitaciones no hay nada que destacar.
#
# Existe una relación casi perfecta entre el precio de compra y el precio total que se puede cobrar.
#
# Parte de este efecto puede ser artificial, ya que usamos el número de habitaciones para calcular el precio total como el precio de compra.

# %%
minicubo_precio.loc['beds_disc']
# Out:
#        precio_total  precio_compra
# value
# 1              59.0       168945.0
# 2             100.0       236523.0
# 3-24          139.0       257355.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['beds_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['beds_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de camas sí hay una conclusión:
#
# **Insight 3: El número de camas a evitar es 3**. O bien ponemos de una a dos camas o ya intentamos meter todas las posibles.
#
# Dado que no había este efecto en el número de habitaciones ¿podría ser que los propietarios estén intentando meter muchas más camas que habitaciones para maximizar el ingreso?
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').precio_total.median().plot();

# %% [markdown]
# Efectivamente aquí hay algo, ya que figura que para pisos de una habitación hay gente que está metiendo hasta decenas de camas!
#
# Sería un tema a explorar con más detalle y comentar con alguien que conozca el negocio.
#
# Vamos a ver unos ejemplos:

# %%
df.loc[(df.bedrooms == 1)& (df.beds > 8)]
# Out:
#        level_0  index        id  \
# 357        357    357   1044902
# 605        605    605   2143824
# 710        710    710   3011110
# 11848    11848  11848  39600798
# 13340    13340  13340  42492960
# 15722    15722  15722  48855617
#
#                                                     name    host_id  \
# 357                                    Masía el Ferrajón    5751753
# 605                    The Hat Madrid - 10 people shared   10940437
# 710                  The Hat Madrid-Compartida 10 pers 2   10940437
# 11848  Bed in a 10-Bed Dormitory In the Centre of Madrid  304035848
# 13340              Apartamento dúplex 10camas en literas  338384437
# 15722   habitaciones en una casa tranquila, en el centro  194738186
#
#       neighbourhood_group         neighbourhood  latitude  longitude  \
# 357     Moncloa - Aravaca  Ciudad Universitaria  40.46549   -3.75115
# 605                Centro                   Sol  40.41511   -3.70804
# 710                Centro           Embajadores  40.41311   -3.70621
# 11848              Centro              Justicia  40.42710   -3.69912
# 13340              Tetuán        Cuatro Caminos  40.44959   -3.70138
# 15722           Salamanca      Fuente del Berro  40.42604   -3.66373
#
#           room_type  price  minimum_nights  calculated_host_listings_count  \
# 357    Private room    112               2                               1
# 605     Shared room     24               1                               6
# 710     Shared room     24               1                               6
# 11848   Shared room     20               1                              13
# 13340  Private room    298               1                               1
# 15722  Private room     36               2                               1
#
#        availability_365                                        description  \
# 357                   0  <b>The space</b><br />Masía el Ferrajón featur...
# 605                 364  10 people shared room with shared bathroom. <b...
# 710                 364  The Hat Madrid es el primer Boutique Hostel de...
# 11848               351  Low-key, hostel-style setup on a tree-lined st...
# 13340               364  Vivienda en planta baja con 10 plazas distribu...
# 15722               359  Es una casa que tiene dos habitaciones que se ...
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 357                   f            16       1.0  14.0                  0
# 605                   t            10       1.0  10.0                 91
# 710                   t            10       1.0  10.0                 28
# 11848                 f             1       1.0  10.0                  2
# 13340                 f            10       1.0  10.0                  1
# 15722                 f             5       1.0   9.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 357                     NaN                          NaN
# 605                    4.57                         4.69
# 710                    4.56                         4.81
# 11848                  5.00                         5.00
# 13340                  5.00                         4.00
# 15722                   NaN                          NaN
#
#        review_scores_location  precio_m2           distrito  precio_total  \
# 357                       NaN       4033  Moncloa - Aravaca        1097.6
# 605                      4.84       4827             Centro         168.0
# 710                      4.93       4827             Centro         168.0
# 11848                    5.00       4827             Centro         140.0
# 13340                    5.00       3678             Tetuán        2086.0
# 15722                     NaN       6114          Salamanca         226.8
#
#        ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 357          100        01_Una              5-16      4-24
# 605            0        01_Una              5-16      4-24
# 710            0        01_Una              5-16      4-24
# 11848          3        01_Una               0-3      4-24
# 13340          0        01_Una              5-16      4-24
# 15722          1        01_Una              5-16      4-24
#
#       number_of_reviews_disc  m2  precio_compra   pdi_sol
# 357                      1-5  50       141155.0  6.767308
# 605                   50-744  50       168945.0  0.436897
# 710                     6-49  50       168945.0  0.470155
# 11848                    1-5  50       168945.0  1.207701
# 13340                    1-5  50       128730.0  3.658902
# 15722                    1-5  50       213990.0  3.510206

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan:

# %%
minicubo_precio.loc['accommodates_disc']
# Out:
#        precio_total  precio_compra
# value
# 0-3            50.0       168945.0
# 4              86.0       168945.0
# 5-16          126.0       236523.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['accommodates_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['accommodates_disc'].precio_compra,color = 'green');

# %% [markdown]
# **Insight 4: El número óptimo de huéspedes está en 4, ya el precio de los inmuebles para acomodar 4 es el mismo que para acomodar 1, 2 o 3. A partir de 5 el piso necesita ser mayor y el precio de compra se incrementa bastante.**

# %% [markdown]
# Por último vamos a analizar la variable que hemos construído de cercanía a un punto de interés para ver si tiene efecto sobre el precio de las habitaciones.
#
# En una situación real hubiéramos construído muchas de este tipo, y repetido el análisis con todas.
#
# En este caso como hemos construído la distancia a la Puerta del Sol vamos a evaluar solo los distritos para lo que esto puede ser relevante, es decir los más céntricos.
#
# Para ello primero vamos a calcular la distancia media por distrito y elegir un punto de corte.

# %%
df.groupby('distrito').pdi_sol.median().sort_values()
# Out:
# distrito
# Centro                    0.728581
# Arganzuela                1.817840
# Chamberí                  2.078790
# Moncloa - Aravaca         2.130135
# Retiro                    2.415432
# Salamanca                 2.705209
# Latina                    3.496952
# Carabanchel               3.647956
# Usera                     3.661376
# Chamartín                 4.233216
# Puente de Vallecas        4.233631
# Tetuán                    4.572866
# Ciudad Lineal             5.170226
# Moratalaz                 5.242395
# Villaverde                7.579665
# Fuencarral - El Pardo     7.738933
# San Blas - Canillejas     7.962141
# Hortaleza                 8.132864
# Vicálvaro                 8.396723
# Villa de Vallecas         8.822907
# Barajas                  11.593340
# Name: pdi_sol, dtype: float64

# %% [markdown]
# Vamos a cortar en Latina incluído.
#
# Y sobre esa selección vamos a visualizar con un scatter.

# %%
df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()
# Out:
# ['Centro',
#  'Arganzuela',
#  'Chamberí',
#  'Moncloa - Aravaca',
#  'Retiro',
#  'Salamanca',
#  'Latina']

# %%
seleccion = df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.distrito.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# No parece haber una relación tan directa como sería esperable entre la distancia a la Puerta del Sol y el precio de alquiler.

# %% [markdown]
# **Insight 5: Estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablmente tengan un precio de compra menor.**

# %% [markdown]
# ### Analisis sobre la ocupación

# %% [markdown]
# Para este punto podríamos repetir exactamente los mismos análisis que con el precio pero cambiando la variable precio por la de ocupación.

# %% [markdown]
# ### Analisis geográfico sobre un mapa

# %% [markdown]
# Para este tipo de análisis podemos usar el paquete **Folium**. Lo único que necesitamos para usarlo es tener las coordenadas de latitud y longitud.

# %%
import folium

# %%
folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_412a3206969a8292e9cfb78c5c8154a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_412a3206969a8292e9cfb78c5c8154a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_412a3206969a8292e9cfb78c5c8154a7 = L.map(
#                 &quot;map_412a3206969a8292e9cfb78c5c8154a7&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_685c3a0e96f9f592e1b384cfadb4b095 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_685c3a0e96f9f592e1b384cfadb4b095.addTo(map_412a3206969a8292e9cfb78c5c8154a7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Por ejemplo vamos a analizar visualmente el insight sobre el distrito de San Blas.

# %%
datos = df[df.distrito == 'San Blas - Canillejas'].copy()

# %% [markdown]
# Para representar los marcadores de todos los pisos tenemos que crear un bucle para ir añadiéndolos al mapa.

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.Marker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a33a78b5af958808cecf2cb74683d25e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a33a78b5af958808cecf2cb74683d25e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a33a78b5af958808cecf2cb74683d25e = L.map(
#                 &quot;map_a33a78b5af958808cecf2cb74683d25e&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21820c40be31b97e5d1731b34d905a59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_21820c40be31b97e5d1731b34d905a59.addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#             var marker_3abbcc108753a3cff52006dcb4645091 = L.marker(
#                 [40.43202, -3.60353],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_16a629974d260f16e7639932e75556ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_602e352db38d7dbb9e6ca9ff95f8015c = $(`&lt;div id=&quot;html_602e352db38d7dbb9e6ca9ff95f8015c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_16a629974d260f16e7639932e75556ed.setContent(html_602e352db38d7dbb9e6ca9ff95f8015c);
#
#
#
#         marker_3abbcc108753a3cff52006dcb4645091.bindPopup(popup_16a629974d260f16e7639932e75556ed)
#         ;
#
#
#
#
#             var marker_79ed3bab1de7a5373222ebffc8664d22 = L.marker(
#                 [40.42756, -3.61577],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_ae6927c43ed5370d16df4ed527015b05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_245595bf2f0dfa1cc7011b51d4bb60ee = $(`&lt;div id=&quot;html_245595bf2f0dfa1cc7011b51d4bb60ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_ae6927c43ed5370d16df4ed527015b05.setContent(html_245595bf2f0dfa1cc7011b51d4bb60ee);
#
#
#
#         marker_79ed3bab1de7a5373222ebffc8664d22.bindPopup(popup_ae6927c43ed5370d16df4ed527015b05)
#         ;
#
#
#
#
#             var marker_47b0fe8db51ed02d42a4278cdc627ebb = L.marker(
#                 [40.42761, -3.6158],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_c31a0563649c70e625f259e35d256fea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1337561b13b845a1a3b7bb87a0d53657 = $(`&lt;div id=&quot;html_1337561b13b845a1a3b7bb87a0d53657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_c31a0563649c70e625f259e35d256fea.setContent(html_1337561b13b845a1a3b7bb87a0d53657);
#
#
#
#         marker_47b0fe8db51ed02d42a4278cdc627ebb.bindPopup(popup_c31a0563649c70e625f259e35d256fea)
#         ;
#
#
#
#
#             var marker_0a0cb562fa97083c6770f467a8e121ea = L.marker(
#                 [40.4267, -3.61631],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_06a5192192a0691e3c8580093dd4d84c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c9699c8f436efd638072a9539018e78 = $(`&lt;div id=&quot;html_9c9699c8f436efd638072a9539018e78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;21.0&lt;/div&gt;`)[0];
#                 popup_06a5192192a0691e3c8580093dd4d84c.setContent(html_9c9699c8f436efd638072a9539018e78);
#
#
#
#         marker_0a0cb562fa97083c6770f467a8e121ea.bindPopup(popup_06a5192192a0691e3c8580093dd4d84c)
#         ;
#
#
#
#
#             var marker_041dc082a263ea6415123f82e7e58f1f = L.marker(
#                 [40.44791, -3.57918],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_010b0564752a9ce9b5e25ac30e9c5ad5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_719fc000d97f21d2e0b7cde4cedf92f4 = $(`&lt;div id=&quot;html_719fc000d97f21d2e0b7cde4cedf92f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;85.0&lt;/div&gt;`)[0];
#                 popup_010b0564752a9ce9b5e25ac30e9c5ad5.setContent(html_719fc000d97f21d2e0b7cde4cedf92f4);
#
#
#
#         marker_041dc082a263ea6415123f82e7e58f1f.bindPopup(popup_010b0564752a9ce9b5e25ac30e9c5ad5)
#         ;
#
#
#
#
#             var marker_8b1474535b4930e1bb3b39156b1d77d9 = L.marker(
#                 [40.44655, -3.58128],
#                 {}
#             ).addTo(map_a33a78b5af958808cecf2cb74683d25e);
#
#
#         var popup_4b5ab171e5571eadd4bbb55d5e8d400

# %% [markdown]
# Esta representación está bien, pero tenemos que ir haciendo click en cada uno para ver el precio.
#
# Sería más fácil si tuviéramos un código de colores que nos indicara visualmente el rango de precio.
#
# Para ello vamos a crear una nueva variable discretizada y cambiaremos el marcador a un círculo de colores.

# %%
datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adebc02009bb14c4353269510bbd0e61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adebc02009bb14c4353269510bbd0e61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adebc02009bb14c4353269510bbd0e61 = L.map(
#                 &quot;map_adebc02009bb14c4353269510bbd0e61&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aac989c9e6d81177a6e59108be14c82b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aac989c9e6d81177a6e59108be14c82b.addTo(map_adebc02009bb14c4353269510bbd0e61);
#
#
#             var circle_marker_5b81c474ca38f343f0ba9ecead81947b = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_adebc02009bb14c4353269510bbd0e61);
#
#
#         var popup_aa7d5e93e8449ce9a484a254e13431f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d7ce44c3541385bdea1fa9841a5877a = $(`&lt;div id=&quot;html_4d7ce44c3541385bdea1fa9841a5877a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_aa7d5e93e8449ce9a484a254e13431f4.setContent(html_4d7ce44c3541385bdea1fa9841a5877a);
#
#
#
#         circle_marker_5b81c474ca38f343f0ba9ecead81947b.bindPopup(popup_aa7d5e93e8449ce9a484a254e13431f4)
#         ;
#
#
#
#
#             var circle_marker_6509503ceb6d965c4ab28a5d27d5df65 = L.circleMarker(
#                 [40.42756, -3.61577],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_adebc02009bb14c4353269510bbd0e61);
#
#
#         var popup_68141504f5b45ad6f9d08a9082356004 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c1f8c81212b4f047be8941db3a8ce57 = $(`&lt;div id=&quot;html_6c1f8c81212b4f047be8941db3a8ce57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_68141504f5b45ad6f9d08a9082356004.setContent(html_6c1f8c81212b4f047be8941db3a8ce57);
#
#
#
#         circle_marker_6509503ceb6d965c4ab28a5d27d5df65.bindPopup(popup_68141504f5b45ad6f9d08a9082356004)
#         ;
#
#
#
#
#             var circle_marker_a7e77ff91c5f3357780358d7828e4aa1 = L.circleMarker(
#                 [40.42761, -3.6158],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_adebc02009bb14c4353269510bbd0e61);
#
#
#         var popup_1654443a6b2c808fbd9685c951d9b652 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_740b7d9f4e9cd0d47d10b8e318b4a267 = $(`&lt;div id=&quot;html_740b7d9f4e9cd0d47d10b8e318b4a267&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_1654443a6b2c808fbd9685c951d9b652.setContent(html_740b7d9f4e9cd0d47d10b8e318b4a267);
#
#
#
#         circle_marker_a7e77ff91c5f3357780358d7828e4aa1.bindPopup(popup_1654443a6b2c808fbd9685c951d9b652)
#         ;
#
#
#
#
#             var circle_marker_b8c7b6d4760e529a7c4ab99e5c18742f = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &qu

# %% [markdown]
# **Insight 6: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos.**
